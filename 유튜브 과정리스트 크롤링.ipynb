# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

#크롬드라이버 열기
driver = webdriver.Chrome('C://chromedriver.exe')
driver.get('https://www.youtube.com/channel/UCW-xgKdaPidxpJ6j6HZPC-g/videos')

#여기서부터
time.sleep(5)
endk = 5
while endk:
    driver.find_element_by_tag_name('body').send_keys(Keys.END)
    time.sleep(0.3)
    endk -= 1
#여기까지

page = driver.page_source
# Out:
# '<html style="font-size: 10px;font-family: Roboto, Arial, sans-serif; " lang="ko-KR"><head><script data-original-src="/yts/jsbin/player_ias-vflCPQUIL/ko_KR/miniplayer.js" src="/yts/jsbin/player_ias-vflCPQUIL/ko_KR/miniplayer.js"></script><script data-original-src="/yts/jsbin/player_ias-vflCPQUIL/ko_KR/remote.js" src="/yts/jsbin/player_ias-vflCPQUIL/ko_KR/remote.js"></script><meta http-equiv="origin-trial" data-feature="Web Components V0" data-expires="2019-08-15" content="AqJc7xVOCYsCYj0w3o6XqSYYRSBYxaX3IhxUyz+piton3LBVj3pWQ3DhcWh75fza5OybeMuuGUxvm/2tmDAJsAkAAABneyJvcmlnaW4iOiJodHRwczovL3lvdXR1YmUuY29tOjQ0MyIsImZlYXR1cmUiOiJXZWJDb21wb25lbnRzVjAiLCJleHBpcnkiOjE1NzMwODQ2OTQsImlzU3ViZG9tYWluIjp0cnVlfQ=="><script>var ytcfg = {d: function() {return (window.yt && yt.config_) || ytcfg.data_ || (ytcfg.data_ = {});},get: function(k, o) {return (k in ytcfg.d()) ? ytcfg.d()[k] : o;},set: function() {var a = arguments;if (a.length > 1) {ytcfg.d()[a[0]] = a[1];} else {for (var k in a[0]) {ytcfg.d()[k] = a[0][k];}}}};window.ytcfg.set(\'EMERGENCY_BASE_URL\', "\\/error_204?client.name=1\\u0026client.version=2.20191015.04.01\\u0026level=ERROR\\u0026t=jserror");</script>  \n<script>var $jscomp=$jscomp||{};$jscomp.scope={};$jscomp.arrayIteratorImpl=function(a){var b=0;return function(){return b<a.length?{done:!1,value:a[b++]}:{done:!0}}};$jscomp.arrayIterator=function(a){return{next:$jscomp.arrayIteratorImpl(a)}};$jscomp.ASSUME_ES5=!1;$jscomp.ASSUME_NO_NATIVE_MAP=!1;$jscomp.ASSUME_NO_NATIVE_SET=!1;$jscomp.SIMPLE_FROUND_POLYFILL=!1;\n$jscomp.defineProperty=$jscomp.ASSUME_ES5||"function"==typeof Object.defineProperties?Object.defineProperty:function(a,b,c){a!=Array.prototype&&a!=Object.prototype&&(a[b]=c.value)};$jscomp.getGlobal=function(a){return"undefined"!=typeof window&&window===a?a:"undefined"!=typeof global&&null!=global?global:a};$jscomp.global=$jscomp.getGlobal(this);$jscomp.SYMBOL_PREFIX="jscomp_symbol_";$jscomp.initSymbol=function(){$jscomp.initSymbol=function(){};$jscomp.global.Symbol||($jscomp.global.Symbol=$jscomp.Symbol)};\n$jscomp.SymbolClass=function(a,b){this.$jscomp$symbol$id_=a;$jscomp.defineProperty(this,"description",{configurable:!0,writable:!0,value:b})};$jscomp.SymbolClass.prototype.toString=function(){return this.$jscomp$symbol$id_};$jscomp.Symbol=function(){function a(c){if(this instanceof a)throw new TypeError("Symbol is not a constructor");return new $jscomp.SymbolClass($jscomp.SYMBOL_PREFIX+(c||"")+"_"+b++,c)}var b=0;return a}();\n$jscomp.initSymbolIterator=function(){$jscomp.initSymbol();var a=$jscomp.global.Symbol.iterator;a||(a=$jscomp.global.Symbol.iterator=$jscomp.global.Symbol("Symbol.iterator"));"function"!=typeof Array.prototype[a]&&$jscomp.defineProperty(Array.prototype,a,{configurable:!0,writable:!0,value:function(){return $jscomp.iteratorPrototype($jscomp.arrayIteratorImpl(this))}});$jscomp.initSymbolIterator=function(){}};\n$jscomp.initSymbolAsyncIterator=function(){$jscomp.initSymbol();var a=$jscomp.global.Symbol.asyncIterator;a||(a=$jscomp.global.Symbol.asyncIterator=$jscomp.global.Symbol("Symbol.asyncIterator"));$jscomp.initSymbolAsyncIterator=function(){}};$jscomp.iteratorPrototype=function(a){$jscomp.initSymbolIterator();a={next:a};a[$jscomp.global.Symbol.iterator]=function(){return this};return a};\n$jscomp.iteratorFromArray=function(a,b){$jscomp.initSymbolIterator();a instanceof String&&(a+="");var c=0,e={next:function(){if(c<a.length){var d=c++;return{value:b(d,a[d]),done:!1}}e.next=function(){return{done:!0,value:void 0}};return e.next()}};e[Symbol.iterator]=function(){return e};return e};\n$jscomp.polyfill=function(a,b){if(b){var c=$jscomp.global;a=a.split(".");for(var e=0;e<a.length-1;e++){var d=a[e];d in c||(c[d]={});c=c[d]}a=a[a.length-1];e=c[a];b=b(e);b!=e&&null!=b&&$jscomp.defineProperty(c,a,{configurable:!0,writable:!0,value:b})}};window.yterr=window.yterr||!0;window.unhandledErrorMessages={};window.unhandledErrorCount=0;\nwindow.onerror=function(a,b,c,e,d){d||(d=Error(),d.message=a,d.fileN ...

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(page,'lxml')

all_title = soup.find_all('a','yt-simple-endpoint style-scope ytd-grid-video-renderer')
title = [soup.find_all('a','yt-simple-endpoint style-scope ytd-grid-video-renderer')[n].string for n in range(0,len(all_title))]
title
# Out:
# ['비밀신간vol.54 감정을 느끼지 못하는 소년',
#  '마법서점 1화, 회사가기 싫을 때 읽었던 책',
#  '아마존vs구글, 누가 미래를 지배할 것인가',
#  'EP2. 대만 여행할 때 꼭 들려야할 힙한 서점들 [타이베이 골목서점 여행기]',
#  'EP1. 대만 오래된서점들의 비결 [타이베이 골목서점 여행기]',
#  '비밀신간vol.53 눈 앞에서 죽은 아들, 보험금을 채근하는 부모',
#  '비밀신간vol.52 유괴하려던 아이의 부모가 죽었다',
#  '천자문을 읽어야 하는 이유',
#  '비밀신간vol51. 유괴된 아기의 엄마, 알고보니 밤새 클럽에..?',
#  '원주가면 꼭 방문할 곳 (feat. 뮤지엄산, 터득골북샵 북스테이)',
#  '영화관에 북카페가 생기면 일어나는 일',
#  '회사 직함 떼고나면 누가 당신을 찾을까?',
#  '비밀신간#50. 전학생에게 매일 배달되는 편지',
#  '일이 우리를 행복하게 할 수 있을까?',
#  '왜 나는 그 이야기만 나오면 화가 날까?',
#  '비밀신간#49 그 날 돌아온 건 동생이 아니었어',
#  '비밀신간#48 여보 창밖에서 자꾸 어떤 남자가 우리를 쳐다봐',
#  '2019 서울국제도서전, 이 부스에 꼭 들러봐',
#  '비밀신간#47 여행지에서 하룻밤을 보낸 남녀',
#  '나는 일주일에 이틀만 일하기로 했다',
#  '비밀신간#46. 서로 죽이고 싶은 사람을 바꿔서 죽여버리자',
#  '딱 10만명만 지구를 탈출해 살아남을 수 있다',
#  '비밀신간#45 언니처럼 성형을 하고 언니를 죽인 용의자를 찾아갔다',
#  '직원들에게 책을 출판시켜주는 게임회사?',
#  '비밀신간#44 코마상태에서 깨어나보니, 연쇄살인범의 아내가 되어있었다',
#  '합정북카페&서점추천 (feat.찌라살롱)',
#  '레시피대로 요리했는데 나만 망치는 이유?',
#  '12가지 인생의 법칙?',
#  '비밀신간#43 현실 남매가 몰래 서로를 챙기는 방법',
#  '펭귄이 연인에게 자갈을 선물하는 이유',
#  '비밀신간#42 친구의 휴대폰에 저장된 아내의 누드사진',
#  '휴, 하마터면 결혼할 뻔했잖아 !',
#  '세계일류기업을 지배한다, 포노사피엔스',
#  '꿈뽕에 빠져 20대를 보낸 청년',
#  '비밀신간#41 국가가 배우자를 정해주기 시작했다',
#  '늘 잘해야한다는 강박에 시달리는 사람들',
#  '비밀신간#40 11살 딸을 입양한 27살 아빠',
#  '인기없던 EBS의 시청율을 역전시킨 PD',
#  '겨울서점의 책을 읽어보았다',
#  '창업 후 혼자 10억 vs 10명이 100억, 당신의 선택은?',
#  '비밀신간#39 나, 고등학교 때 사람을 죽였어',
#  "'진짜 나'를 찾아 방황 중인 당신에게",
#  '불안한 사람들의 공통점',
#  '나를 성장시키는 인생책 100권',
#  '비밀신간#38 이름 순대로 살해 당하는 사람들',
#  '108 번뇌를 잊게 해준다는 프랑스 자수',
#  '새해 각오: 도망칠 용기, 열심히 살지 않을 용기',
#  '외로움을 이길 수 있는 방법',
#  '비밀신간#37 스카이캐슬? 일본 명문고 천재가 선생님에게 복수하는 방법',
#  '새해각오와(!) 독서모임 공지',
#  '우리는 일상속에서 얼마나 많은 화학물질을 섭취할까?',
#  '비밀신간#36 병든 엄마를 돌보면서 빨리 죽기를 바라는 아들',
#  '불안에 압도당해본 적이 있나요',
#  '비밀신간#35 이혼하지 않기 위해 바람 피우는 남자',
#  '흥행의 조건 : Most Advanced Yet Acceptable',
#  'CEO 엄마가 외동딸에게 남긴 유산',
#  '비밀신간#34 좋아요를 가장 많이 받은 사람이 죽는 게임',
#  '이불에서 나오기 싫은 나, 만성피로일까?',
#  '좋아하는 일만해서 먹고 살 수 있을까',
#  '방금 그 말씀은 듣기가 좀 불편하네요',
#  '비밀신간#33 짝사랑의 3가지 아이러니',
#  '우리가 행복할 수 없는 이유',
#  '취향이 없는 나를 위한 새로운 취미, 그림책 만들기',
#  '하트시그널이 대박 친 진짜 이유?',
#  '클.알.못을 위한 클래식 시작하는 방법',
#  '트렌드 코리아가 예측한 2019 키워드 #2 카멜레존',
#  '비밀신간#32 고구려에 좀비가 있었다면?',
#  '트렌드 코리아가 예측한 2019 키워드, 컨셉',
#  "'진지함'에 대한 진지한 고찰",
#  '나는 부모가 원망스럽다',
#  '프로이트가 무의식을 역설한 이유',
#  '유난히 비난이 견디기 힘든 사람들',
#  '헤어지고 충분한 애도를 하지 못했을 때',
#  '비밀신간#31 차인 사람들을 위한 소설',
#  '무고한 내 친구가 경찰의 총에 죽었어요',
#  '성실한 경찰이  사랑과 권력에 눈이 멀면 생기는 일',
#  '교토에서의 청춘 판타지',
#  '내가 사는 곳에 대해 생각해봐야 할 것',
#  '페미니즘 팝니다',
#  '하버드 학생들이 꿈을 이루는 비결',
#  '한 달에 월급 11번 받는 남자, 박용후',
#  '누군가 페이스북에서 내 행세를 하고 다닌다?',
#  '비밀신간#29 일가족 몰살 사건, 누구의 원한일까?',
#  '[라이브]모으지 않는 연습',
#  '비밀신간#28 바람 피우다 걸린 후 여자를 죽인 내연남',
#  '무례한 프랑스인들이 행복한 이유',
#  '에베레스트를 처음 정복한 남자가 남긴 말(feat.이근철 선생님)',
#  '히키코모리의 하루',
#  '인간이 되기 위한 조건?',
#  '내가 우울증을 견뎌냈던 방법',
#  '일을 하는 게 정말 당연한 걸까?',
#  '책읽찌라가 책을 냈어요! 우울증에 대해서.',
#  '비밀신간#27 이 중에 누군가 우리를 죽이고 있어',
#  'EP13 폐쇄병동에 대해 당신이 오해하는 것들',
#  '책 읽어주는 영상 시작합니다 (ft.밀리의서재)',
#  '결정 잘 하는 사람들의 비결',
#  '비밀신간#26 그녀는 왜 달려오는 기찻길 위에 누워있었을까',
#  '발달장애인 혜정의 ‘자립’이야기 (ft. 생각많은 둘째언니)',
#  '휴~하마터면 열심히 살 뻔 했다.',
#  '비밀신간#25 분필로 살인을 예고하는 살인마',
#  '재능 없이 글 쓰는 방법?',
#  '비밀신간#24 어리고 잘생긴 재벌 2세 남편.. 점점 드러나는 광기',
#  '살해당한 딸, 시한부 엄마가 부탁한 복수',
#  '아무것도 안 하면 불안한 이유?',
#  '비밀신간#23 자살한 친구가 페친을 걸어왔다',
#  '다이어트는 의지력이 아니라 OOO다',
#  '암호화폐가 혁신인 이유? = 탈중앙화(Decentralize)',
#  '글 쓰는 두려움을 줄이는 세 가지 방법',
#  '비밀신간#22 내가 왜 널 가둔지 모르겠어?',
#  '문재인부터 이승만까지, 외신이 본 대통령',
#  '당신을 지켜주는 직관, 서늘한 신호',
#  '아버지대신 막노동을 뛰는 아이',
#  '비밀신간#21 네가 이 집에서 나가줘야겠어',
#  '하루 중 일하기에 최적인 시간은 언제?',
#  '김정은은 왜 갑자기 태도를 바꿨나',
#  '꼰대가 되면 안 되는 이유?',
#  '2000만원으로 100억원까지 불린 장사 고수의 비결',
#  '더 생생하게 돌아온다, 비밀신간 시즌3',
#  '원센텐스에서 책읽찌라로 피봇한 이유',
#  '첫사랑과 10년 연애하고 결혼한 썰',
#  '설득 고수에게 휘말리지 않는 법 3가지',
#  '소심한 심리학',
#  '남편과 사별 후 캠핑카에 오른 엄마',
#  '그로스해킹 3분 핵심 요약 정리',
#  '리더십 고수들의 5가지 공통점',
#  '의사소통의 4단계, 공감의 언어',
#  '책 만드는 여자 x 책 읽어주는 여자의 책수다',
#  '엄마는 늘 말했다, "너는 뭐든 할 수 있는 사람이야!"',
#  '몇 시간 연락 안했다고 갑자기 헤어지자는 여자친구 심리, 도대체 뭘까?',
#  '니체가 [차라투스트라는 이렇게 말했다]의 영감을 얻은 곳',
#  '부동산이 아니라 빚동산? 주택과잉시대, 오래된 집',
#  '구글의 인사채용 기준 4가지',
#  '비밀신간#20 썸녀와 1박 2일 여행 중, 동거녀를 마주쳤다',
#  '츠타야, 뭐가 좋길래? 핵심은 큐레이션!',
#  '지금껏 비효율적으로 일해왔다면, 스프린트',
#  '책읽찌라의 인생책, 하워드의 선물',
#  '비밀신간#29 쓰레기 봉지 속에서 발견된 아이',
#  '가정 지출 줄이는 3가지 꿀팁!',
#  '나는 왜 다른 사람의 말에 쉽게 욱하고 무너질까?',
#  '혼자 있고 싶어서 집에 왔는데 금세 또 외로워지는 것, 정상일까?',
#  '비밀신간#18 나는 그를 살해하지 않았어!',
#  "독서앱 추천 ㅣ 개인화해서 책 골라주는 '책방 잉크'",
#  '써 먹을 데가 없는데도 공부를 해야할까? 『공부의 철학』',
#  '마이크로소프트가 10년 후에도 살아남아있을까?',
#  '퇴사하고 유럽여행 떠난 남녀 ㅣ 퇴사할 때 꼭 챙길 것, 퇴직금과 휴가, 유럽여행 경비... ㅣ 퇴사하고 여행갑니다',
#  '나에게 마흔이란 오지 않을 줄 알았다 『오늘의 나이, 대체로 맑음』',
#  '비밀신간#17 살해된 딸, 자살한 아내… 진범을 밝힐 때까지 난 죽지 않겠어',
#  '압록강을 아홉번 넘어 독립자금 조달한 조선의 잔다르크 정정화 의사 ㅣ 찌라시한국사',
#  '아들아, 나라를 위해 목숨을 내놓았다면 그냥 죽으라ㅣ 안중근 의사 어머니의 편지 ㅣ 찌라시한국사(2)',
#  '이성계의 아버지가 이인임?! 조선의 200년 숙제, 종계변무를 푼 역관 홍순언 ㅣ 찌라시 한국사(1)',
#  '진짜 선생님을 만나다,  『라틴어수업』 ㅣ 비인기 제2외국어 수업에 정원이 가득찬 이유 ㅣ 한동일 교수님',
#  '남자친구의 스토커, 알고보니 그녀가 나의 환자로 계속 찾아오고 있었다면? 『당신이 내게 최면을 걸었나요?』 ㅣ 허즈번드 시크릿의 리안 모리아티 소설 ㅣ 책읽찌라',
#  '배달의 민족 김봉진 대표의 "책 잘 읽는 방법" ㅣ 독서가 어려웠던 분들을 위한  꿀팁 대방출 ㅣ 책읽찌라 인터뷰',
#  '비밀신간#16 광화문 사거리, 여성 머리 유기 사건 (심약자주의)',
#  '찌라책방 사은품 북킷리스트 제작해봤어용 ! ㅣ 도서 2,000원 할인쿠폰도 준비했어요 ㅣ 쿠폰명 : 하이찌라',
#  '[호텔 캘리포니아] 죽은 아내의 배아를 낳아줄 대리모를 찾습니다 ㅣ 책읽찌라 EP113',
#  '[가장 빨리 부자 되는 법] 부자가 되고 싶다고? 컴포트 존을 떠나라! ㅣ30대 백만장자 알렉스 베커의 부자전략ㅣ 책읽찌라 EP112',
#  '비밀신간#15 누가 아름다운 그녀를 죽였을까?',
#  '[무조건 달라진다] 의지 따위 없어도 저절로 행동이 바뀌는 습관의 과학 ㅣ  책읽찌라EP110',
#  '[세상을 바꾸는 언어]  빨갱이? 좌파? 뜻은 알고 쓰자! ㅣ 양정철의 언어 민주주의 ㅣ 책읽찌라 EP109',
#  '[책읽찌라EP109] 마음으로 바라보기 ㅣ 무관심 속에 죽어간 어미판다 이야기 ㅣ 연탄길 이철환 작가님의 어른들을 동화',
#  '[책읽찌라 비밀신간] 300만뷰 돌파 이벤트 ㅣ 이야기만으로 사람들이 책을 살까?',
#  '비밀신간#14 아들을 유괴당한 천재화가가 남긴 마지막 메시지 "내 아들은 살아있다"',
#  '[책읽찌라 EP106] 7일 공부법 l 시험에 반드시 합격하는 공부전략 ㅣ 스즈키히데야키',
#  '[책읽찌라 EP105] 빅매직 (Big Magi) l 먹고 기도하고 사랑하라의 엘리자베스 길버트 ㅣ 크리에이터들에게 추천도서 ㅣ 창조적 삶을 사는 법',
#  '[책읽찌라EP98] 하나로 연결된 삶 ㅣ A continuous line drawing l Seoul Drawing With One Line',
#  "[책읽찌라 EP104] 내 안 에서 나를 만나는 것들 ㅣ 원제: 애덤 스미스의 '도덕감정론' ㅣ 애덤스미스의 아이러니3",
#  '[책읽찌라 EP101] 나를 넘다 ㅣ 우리는 우리가 아는 것을 어떻게 아는가  ㅣ',
#  '[책읽찌라EP100] 네팔 히말라야 안나푸르나 트래킹 다녀왔어요 ㅣ 셀프 여행 영상',
#  "[책읽찌라 EP99]  찌질한 인간 김경희 ㅣ 회사가 싫어서 작가 '너구리' 의 속편 백수 이야기",
#  '[책읽찌라EP96] 우리는 언젠가 만난다 ㅣ #02 노력에 대하여 말하다 ㅣ 채사장 인터뷰',
#  '[책읽찌라EP95] 우리는 언젠가 만난다 ㅣ #01 이별에 대하여 말하다 ㅣ 채사장 인터뷰',
#  '[책읽찌라 EP94] 라이프스토밍 l 너도 할수있다구!라는 말만하는 꿈뽕을 조심해야 하는 이유 l 트리거의 저자 마셜 골드스미스',
#  '[책읽찌라EP91] 결정적인 순간에 써먹는 선택의 기술 l 합리적 의사결정을 도와주는 행동경제학 l 넛지 리처드 탈러 추천',
#  '[책읽찌라EP90] 빅프라핏 ㅣ 타타그룹은 어떻게 2만원짜리 정수기를 만들었을까 ㅣ 기업의 공유가치창출(CSV) , 선택이 아니라 생존의 조건이다',
#  '[책읽찌라 X 비밀신간#12] 아이가 되어 돌아온 그녀 (계속 환생하는 여자 ㅣ 로맨스소설 ㅣ 환타지 ㅣ 소설 ㅣ 소설추천)',
#  '[책읽찌라 EP84] 2018 대한민국 트렌드 ㅣ 저자 인터뷰 ㅣ 마이크로엠브로밀',
#  '[책읽찌라EP82] 블록체인노믹스 ㅣ 블록체인 거래가 파괴적 혁신을 불러오고 있다',
#  '[책읽찌라EP79] 화재위험, 우리 집은 얼마나 안전할까?',
#  '[책읽찌라EP68] 장애아 특수학교 갈등.. Fact는?  ㅣ 중앙일보 디지털 스페셜 (2)',
#  '[책읽찌라EP78] 일하는 문장들 ㅣ 백우진 ㅣ 업무메일, 제안서 짧고 간결하게 쓰는 꿀팁',
#  '[책읽찌라 EP77] 말그릇 ㅣ ‘헤어져’ 라는 말에 대한 정답',
#  '[책읽찌라 EP76] 나는 4시간만 일한다 l  일의 노예를 탈출하기 위한 팀페리스의 비결',
#  '[책읽찌라 EP64] 강남 집값이 하늘을 찌르는 진짜 이유 l 중앙일보 디지털스페셜',
#  '[책읽찌라 EP74] 미라클 라이프 (Miracle Life) ㅣ 고통이 당신을 쥐고 흔들 때',
#  '[책읽찌라EP73] 디지털 노마드 ㅣ권강현, 박영훈 ㅣ 라온북 ㅣ  내가 원하는 곳에서 원하는 대로 일하고 돈버는 사람들',
#  '비밀신간#10  전쟁터에서 벌어지는 미스터리한 사건',
#  '[책읽찌라 EP70] 가까운 날들의 사회학 ㅣ 카페가 독서실을 대체하는 이유',
#  '[책읽찌라 EP69]  대량살상수학무기 l 빅데이터가 민주주의를 위협한다? ㅣ 캐시 오닐',
#  '[책읽찌라x비밀신간 EP58]',
#  '[책읽찌라EP61] 소나기 ㅣ 황순원 원작 ㅣ 안재훈 감독 애니매이션',
#  '[책읽찌라EP67] 탑차트(3)‘노벨문학상’에 대해 우리가 알지 못했던 네 가지 l 가즈오 이시구로',
#  '[책읽찌라EP66] 그녀를 모르는 그에게 l 존 가트맨 ㅣ 연애책',
#  '비밀신간#09 쉬어도 쉬어도 피로한 당신에게 구글, 애플, 페이스북의 휴식법',
#  '[책읽찌라 EP63] 생산성 (기업 제1의 존재 이유 | 생산성 높은 기업이 가장 창의적인 기업이다) l 이가 야스요ㅣ 쌤앤파커스',
#  '[책읽찌라 북토크] 김홍신 작가님 ㅣ 바람으로 그린 그림 ㅣ 코엑스 북토크',
#  '[책읽찌라 인터뷰] 불안이라는 위안 ㅣ 김혜령 작가님',
#  '[책읽찌라EP62] 이직할 때 꼭 확인해야 할 것 x더팀스',
#  '[책읽찌라 EP50] 커넥츠북 탑차트 자존감이 떨어졌을 때',
#  '[책읽찌라 EP60]  북숍스토리 (BOOKSHOP STORY)  l  젠 캠벨 (Jen Campbell)',
#  '[책읽찌라x인터뷰] 주진우의 이명박 추격기 : 저수지를 찾아라ㅣ 주진우 기자',
#  '[책읽찌라EP47 / Motiv] 누가 내 돈을 훔쳤을까(1)',
#  '[책읽찌라55] 5초의 법칙',
#  '[책읽찌라] 흡연자는 세금셔틀? 담뱃값논란 총정리 ㅣ 누가 내돈을 훔쳤을까',
#  '[책읽찌라x커넥츠북 탑차트] 연애세포를 깨워주는 사랑소설 4',
#  '[책읽찌라EP53] 시시하게 살지 않겠습니다',
#  '비밀신간#04 너 왜 내 비밀을 알아버렸지?',
#  '[책읽찌라EP50] 힐빌리의 노래 l J.D. Vance 제이디 밴스',
#  '[책읽찌라 EP49] 누가내돈을 훔쳤을까 (2) 일자리감소와 인구절벽 위기론의 함정',
#  '[책읽찌라] 소개영상',
#  '[책읽찌라] 비밀신간3탄 언박싱영상!!',
#  '비밀신간#05 결혼과 성관계가 분리된 사회',
#  '[책읽찌라 EP45] 뭘해도되는사람',
#  '[책읽찌라 EP44] 슬픈열대 ㅣ 해원',
#  '[책읽찌라] 태백산맥 ㅣ 조정래 ㅣ 해냄',
#  '[책읽찌라] 휴가지에서 읽는 철학책',
#  '[책읽찌라41] 공터에서 ㅣ 김훈',
#  '비밀신간#01 사이코패스 남편',
#  '[책읽찌라EP33] 광개토태왕 ㅣ 손정미',
#  '펜과 종이만으로 언제 어디서나 일상드로잉(2) 카페에서 할수 있는 공간 그리기 ㅣ  김효찬',
#  '[책읽찌라 EP32] 천 명의 눈 속에는 천 개의 세상이 있다',
#  '펜과 종이만으로 언제 어디서나 일상드로잉(3)  밑그림 없이 그리는 드로잉 방법ㅣ 김효찬',
#  '[책읽찌라 EP32] 도시생활자의 책읽기 ㅣ 책읽는지하철',
#  '[책읽찌라 EP30] 보복대행전문주식회사 l 이외수',
#  '펜과 종이만으로 언제 어디서나 일상드로잉(1)  드로잉할때 꼭 기억해야 할 4가지ㅣ 김효찬',
#  '[책읽찌라 EP29] 마크드포라이프 ㅣ 에멜리에 셰프',
#  '[책읽찌라 EP28] 스마트체인지 ㅣ 아트마크먼',
#  '[책읽찌라 EP27] 음란한인문학 ㅣ 이봉호',
#  '[서울국제도서전] 올해 서울국제도서전에 꼭 가야하는 이유',
#  '[서울국제도서전] 독서클리닉, 은유작가에게 묻다',
#  '[서울국제독서전] 독서클리닉, 이정모 관장님께 묻다',
#  '[서울국제독서전] 독서클리닉, 서민 교수님에게 묻다',
#  '[2017 SIBF 서울국제도서전] 서점의 시대 기획전',
#  '[책읽찌라 EP25] 한마디면 충분하다 ㅣ 장문정 ㅣ 쌤앤파커스',
#  '[2017 SIBF 서울 국제도서전] 독서클리닉 ㅣ 이정모, 은유, 서민',
#  '[책읽찌라 EP22] 나는 뻔뻔하게살기로했다 ㅣ',
#  '[책읽찌라 EP21] 보노보노처럼살다니 다행이야  l 성년의날 추천 ㅣ 김신회',
#  '[책읽찌라 EP20] 당신, 거기있어줄래요 ㅣ 로즈데이 추천ㅣ 기욤 뮈소',
#  '[책읽찌라 EP19] 아마존, 세상의 모든 것을 팝니다',
#  '[책읽찌라 EP18] 어서와 전월세는 처음이지? ㅣ 구본기 ㅣ 3분영상',
#  '[책읽찌라 EP11] 완벽한 공부법 02 ㅣ 고영성, 신영준 ㅣ 3분영상',
#  '[책읽찌라 EP17] 손정의 제곱법칙 ㅣ 이타가키 에이켄  ㅣ 3분영상',
#  '[책읽찌라 EP10] 완벽한 공부법 01 ㅣ고영성, 신영준 ㅣ 3분영상',
#  '[책읽찌라 EP16] 할머니는죽지않는다 ㅣ 공지영  ㅣ 3분영상',
#  '[책읽찌라 EP15] 대통령 조건 l  최명기 ㅣ3분영상',
#  '[책읽찌라 EP12] 에고라는 적 ㅣ 라이언 홀리데이',
#  '[책읽찌라 EP08] 리씽크 Rethink ㅣ스티븐 풀 ㅣ 3분영상',
#  '[책읽찌라 EP07] 아Q정전 ㅣ 루쉰ㅣ 3분영상',
#  '[책읽찌라 EP06] 모든 순간의 물리학 ㅣ 카를로 로벨리ㅣ 3분영상',
#  '[찌라의 무작정따라하기01] 영어리딩 무작정 따라하기 ㅣ 이선욱 선생님ㅣ 길벗',
#  '[책읽찌라 EP05]  모든 비즈니스는 브랜딩이다 ㅣ 홍성태 ㅣ 3분영상',
#  '[책읽찌라162] 비혼입니다만, 그게 어쨌다구요? ㅣ 3분영상',
#  '[책읽찌라157] 이본, 그 여자의 뷰티ㅣ 라이브 ㅣ저자출연 이본,곽민지',
#  '[책읽찌라160] 끌림의과학ㅣ라이브',
#  '[책읽찌라159] 끌림의과학ㅣ3분영상',
#  '[책읽찌라156] 사람의 목소리는 빛보다 멀리간다ㅣ라이브ㅣ 위화',
#  '[책읽찌라155] 사람의 목소리는 빛보다 멀리간다ㅣ3분요약ㅣ 위화',
#  '[책읽찌라154 x 11번가] 나는까칠하게 살기로했다 ㅣ 양창순 저자출연',
#  '[책읽찌라153] 타임푸어 Time Poor(2) l 더퀘스트',
#  '[책읽찌라152] 타임푸어 Time Poor(1) l 더퀘스트',
#  '[책읽찌라151x11번가] 해피엔딩노트 ㅣ tvNㅣ북폴리오',
#  '[책읽찌라150] 싱크심플 Think Simple (2)ㅣ켄 시걸 ㅣ 문학동네',
#  '[책읽찌라149]  Think Simple(1) ㅣ 켄 시걸 ㅣ 문학동네',
#  '[책읽찌라148 x 11번가] 주원홈트 플랜북 ㅣ 김주원 ㅣ싸이프레스',
#  '[책읽찌라147] 더패스 The Path (2) ㅣ 마이클 푸엣 , 크리스틴 그로스 ㅣ 김영사',
#  '[책읽찌라146] 더패스 The Path (1) ㅣ 마이클 푸엣 , 크리스틴 그로스 ㅣ 김영사',
#  '[책읽찌라 145] 이근철의 Try Again l 이근철 선생님 출연',
#  '[책읽찌라144 x 11번가] 월급쟁이 재테크 상식사전 ㅣ 우용표 저자출연',
#  '[책읽찌라143] 오리지널스(2) ㅣ 애덤그린트 ㅣ 한국경제신문',
#  '[책읽찌라142] 오리지널스(1) ㅣ 애덤그린트 ㅣ 한국경제신문']

# %%
all_video_time = soup.find_all('span','style-scope ytd-thumbnail-overlay-time-status-renderer')
video_time = [soup.find_all('span','style-scope ytd-thumbnail-overlay-time-status-renderer')[n].string.strip() for n in range(0,len(all_video_time))]
video_time
# Out:
# ['2:52',
#  '10:29',
#  '23:31',
#  '10:34',
#  '11:40',
#  '5:08',
#  '5:15',
#  '19:04',
#  '5:14',
#  '12:52',
#  '5:08',
#  '7:15',
#  '5:18',
#  '19:03',
#  '12:34',
#  '4:39',
#  '4:37',
#  '14:52',
#  '6:56',
#  '18:13',
#  '3:41',
#  '4:23',
#  '6:55',
#  '10:49',
#  '2:49',
#  '19:03',
#  '5:59',
#  '22:29',
#  '6:30',
#  '3:54',
#  '3:04',
#  '8:19',
#  '4:54',
#  '15:34',
#  '7:25',
#  '17:16',
#  '3:09',
#  '10:09',
#  '4:02',
#  '38:19',
#  '6:23',
#  '3:39',
#  '32:14',
#  '5:08',
#  '5:04',
#  '4:46',
#  '2:35',
#  '28:14',
#  '8:15',
#  '10:58',
#  '17:59',
#  '3:55',
#  '27:42',
#  '5:20',
#  '22:40',
#  '3:18',
#  '3:23',
#  '2:08',
#  '4:27',
#  '4:45',
#  '7:19',
#  '39:07',
#  '9:16',
#  '3:50',
#  '4:45',
#  '4:18',
#  '4:36',
#  '4:06',
#  '15:17',
#  '2:06',
#  '21:24',
#  '2:06',
#  '2:09',
#  '7:22',
#  '3:23',
#  '3:51',
#  '2:16',
#  '39:22',
#  '16:17',
#  '36:31',
#  '3:04',
#  '2:59',
#  '4:56',
#  '18:10',
#  '3:59',
#  '3:35',
#  '4:55',
#  '4:21',
#  '19:22',
#  '5:47',
#  '11:40',
#  '2:17',
#  '4:17',
#  '6:06',
#  '2:02',
#  '3:21',
#  '4:00',
#  '5:49',
#  '4:33',
#  '4:35',
#  '4:26',
#  '3:21',
#  '2:56',
#  '3:37',
#  '2:51',
#  '3:14',
#  '3:09',
#  '3:05',
#  '3:01',
#  '4:11',
#  '3:14',
#  '3:12',
#  '2:54',
#  '2:44',
#  '4:23',
#  '4:38',
#  '1:01',
#  '2:57',
#  '9:20',
#  '5:06',
#  '4:57',
#  '3:29',
#  '4:12',
#  '3:56',
#  '4:31',
#  '4:28',
#  '51:05',
#  '3:15',
#  '3:31',
#  '3:27',
#  '3:23',
#  '3:18',
#  '3:26',
#  '3:50',
#  '5:26',
#  '6:15',
#  '4:23',
#  '4:52',
#  '2:35',
#  '3:30',
#  '2:35',
#  '7:43',
#  '4:38',
#  '4:41',
#  '5:40',
#  '3:33',
#  '2:45',
#  '6:58',
#  '7:20',
#  '6:57',
#  '3:21',
#  '2:15',
#  '7:55',
#  '2:10',
#  '2:30',
#  '3:04',
#  '2:37',
#  '2:46',
#  '3:34',
#  '2:39',
#  '3:12',
#  '2:13',
#  '2:21',
#  '3:08',
#  '3:15',
#  '5:25',
#  '2:46',
#  '3:10',
#  '8:25',
#  '2:43',
#  '5:51',
#  '3:20',
#  '3:26',
#  '3:05',
#  '2:12',
#  '5:23',
#  '6:22',
#  '4:55',
#  '4:31',
#  '4:31',
#  '3:23',
#  '4:14',
#  '4:13',
#  '3:28',
#  '3:34',
#  '2:35',
#  '2:45',
#  '3:08',
#  '3:54',
#  '2:56',
#  '3:46',
#  '3:08',
#  '3:45',
#  '3:33',
#  '2:52',
#  '2:05',
#  '3:13',
#  '4:03',
#  '2:18',
#  '2:46',
#  '3:56',
#  '3:18',
#  '2:23',
#  '2:50',
#  '2:02',
#  '3:24',
#  '2:38',
#  '3:25',
#  '3:21',
#  '0:43',
#  '1:46',
#  '2:59',
#  '2:52',
#  '2:47',
#  '3:50',
#  '3:18',
#  '3:19',
#  '4:09',
#  '4:19',
#  '2:43',
#  '2:51',
#  '3:02',
#  '1:34',
#  '2:27',
#  '2:16',
#  '1:55',
#  '3:06',
#  '3:02',
#  '1:28',
#  '36:52',
#  '25:19',
#  '35:28',
#  '3:34',
#  '3:36',
#  '3:30',
#  '3:11',
#  '3:31',
#  '2:09',
#  '4:12',
#  '2:59']

# %%
#채널명
chennel = soup.find('yt-formatted-string','style-scope ytd-channel-name').string
#구독자 수
sub_num = soup.find('yt-formatted-string','style-scope ytd-c4-tabbed-header-renderer').string
#조회수, 올린지 얼마나 되었는지(업로드 시점)
c = soup.find_all('span','style-scope ytd-grid-video-renderer')
view_num = [soup.find_all('span','style-scope ytd-grid-video-renderer')[n].string for n in range(0,len(c))]

# %%
from time import localtime, strftime

...

#현재 시간
extract_date = strftime("%Y/%m/%d %H:%M:%S", localtime())
extract_date

#결과 : 2019/05/20 20:36:49
# Out:
# '2019/10/16 18:10:53'

# %%
youtube_video_list = []

x = 0		#조회수의 index
y = 1		#업로드 시점의 index

for i in range(0,len(all_title)):
    roww = []
    roww.append(title[i])
    roww.append(video_time[i].strip())
    roww.append(chennel)
    roww.append(sub_num)
    roww.append(view_num[x])
    x += 2		#조회수만 append
    roww.append(view_num[y])
    y += 2		#업로드 시점만 append
    roww.append(extract_date)
    youtube_video_list.append(roww)			#2차원 list로 만들어줌
    
    youtube_video_list
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-22-3d20b7c17d26> in <module>
#       7     roww = [1]
#       8     roww.append(title[i])
# ----> 9     roww.append(video_time[i].strip())
#      10     roww.append(chennel)
#      11     roww.append(sub_num)
#
# IndexError: list index out of range

# %%
len(title)
len(video_time)
len(chennel)
# Out:
# 4
